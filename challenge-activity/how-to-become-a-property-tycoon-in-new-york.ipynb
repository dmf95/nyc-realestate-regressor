# %% [markdown]
# # Overview
# How to predict House Prices and hopefully become a Property Tycoon in New York
#
# * I am going to clean and visualise data and build a model to predict housing prices in New York.
# * Everything is done obviously with the aim of becoming a property tycoon - one of the most important things to know in order to achieve that is the value of a property.
# * So without further ado, let's go for it.
#
# Credit: https://www.kaggle.com/code/akosciansky/how-to-become-a-property-tycoon-in-new-york

# %% [markdown]
# Credit: https://www.kaggle.com/code/akosciansky/how-to-become-a-property-tycoon-in-new-york

# %% [markdown]
# * I am going to clean and visualise data and build a model to predict housing prices in New York.
# * Everything is done obviously with the aim of becoming a property tycoon - one of the most important things to know in order to achieve that is the value of a property.
# * So without further ado, let's go for it.

# %% [markdown]
# # -1- load dependencies
# * libraries

# %%
# Import the modules

import pandas as pd
import numpy as np
from scipy import stats
import sklearn as sk
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set(style='white', context='notebook', palette='deep') 
import matplotlib.style as style
style.use('fivethirtyeight')


from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import GridSearchCV

# Data Scaler
from sklearn.preprocessing import StandardScaler

# Regression
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet

# Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # -2- data
# * get data
# * clean data
# * explore / inspect data

# %% [markdown]
# ### 2.1 get data

# %%
# Read the data
data = pd.read_csv('nyc-rolling-sales.csv')

# %% [markdown]
# ### 2.2 clean data

# %% [markdown]
# Let's update the **BOROUGH** names first according to the instructions found on Kaggle.

# %%
# Renaming BOROUGHS
data['BOROUGH'][data['BOROUGH'] == 1] = 'Manhattan'
data['BOROUGH'][data['BOROUGH'] == 2] = 'Bronx'
data['BOROUGH'][data['BOROUGH'] == 3] = 'Brooklyn'
data['BOROUGH'][data['BOROUGH'] == 4] = 'Queens'
data['BOROUGH'][data['BOROUGH'] == 5] = 'Staten Island'

# %%
# Change the settings so that you can see all columns of the dataframe when calling df.head()
pd.set_option('display.max_columns',999)
data.head()
# Out:
#    Unnamed: 0    BOROUGH   NEIGHBORHOOD  \
# 0           4  Manhattan  ALPHABET CITY
# 1           5  Manhattan  ALPHABET CITY
# 2           6  Manhattan  ALPHABET CITY
# 3           7  Manhattan  ALPHABET CITY
# 4           8  Manhattan  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0    6                                  C2            153 AVENUE B
# 1   26                                  C7   234 EAST 4TH   STREET
# 2   39                                  C7   197 EAST 3RD   STREET
# 3   21                                  C4     154 EAST 7TH STREET
# 4   55                                  C2  301 EAST 10TH   STREET
#
#   APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                      10009                  5                 0
# 1                      10009                 28                 3
# 2                      10009                 16                 1
# 3                      10009                 10                 0
# 4                      10009                  6                 0
#
#    TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  YEAR BUILT  \
# 0            5             1633              6440        1900
# 1           31             4616             18690        1900
# 2           17             2212              7803        1900
# 3           10             2272              6794        1913
# 4            6             2369              4615        1900
#
#    TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                          2                             C2    6625000
# 1                          2                             C7        -
# 2                          2                             C7        -
# 3                          2                             C4    3936272
# 4                          2                             C2    8000000
#
#              SALE DATE
# 0  2017-07-19 00:00:00
# 1  2016-12-14 00:00:00
# 2  2016-12-09 00:00:00
# 3  2016-09-23 00:00:00
# 4  2016-11-17 00:00:00

# %% [markdown]
# What we can see by looking at the first few rows is that the column Unnamed: 0 is an artifact from the data load and is not needed. The column EASEMENT is completely empty and will be deleted. And there some missing Sale Prices.

# %% [markdown]
# **Update Data**

# %% [markdown]
# I have already done some prior inspection of the data and am now updating the dataset by deleting columns and changing the data type of some of the variables.

# %%
#EASE_MEANT is empty and can be dropped
del data['EASE-MENT']

# Unnamed: 0 is an artifact from the data load and can be deleted
del data['Unnamed: 0']

# %%
#SALE PRICE is object but should be numeric
data['SALE PRICE'] = pd.to_numeric(data['SALE PRICE'], errors='coerce')

#LAND and GROSS SQUARE FEET is object but should be numeric
data['LAND SQUARE FEET'] = pd.to_numeric(data['LAND SQUARE FEET'], errors='coerce')
data['GROSS SQUARE FEET']= pd.to_numeric(data['GROSS SQUARE FEET'], errors='coerce')

#SALE DATE is object but should be datetime
data['SALE DATE'] = pd.to_datetime(data['SALE DATE'], errors='coerce')

#Both TAX CLASS attributes should be categorical
data['TAX CLASS AT TIME OF SALE'] = data['TAX CLASS AT TIME OF SALE'].astype('category')
data['TAX CLASS AT PRESENT'] = data['TAX CLASS AT PRESENT'].astype('category')

# %% [markdown]
# After updating the data let's check if there are any duplicate values in here.

# %%
sum(data.duplicated(data.columns))
# Out:
# 765

# %% [markdown]
# There are 765 duplicates. Let's remove them

# %%
#Delete the duplicates and check that it worked
data = data.drop_duplicates(data.columns, keep='last')
sum(data.duplicated(data.columns))
# Out:
# 0

# %% [markdown]
# ### 2.3 data inspection

# %%
# Check the number of rows and columns
data.shape
# Out:
# (83783, 20)

# %%
# Get a high-level overview of the data types, the amount of NULL values etc.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         83783 non-null  object
#  1   NEIGHBORHOOD                    83783 non-null  object
#  2   BUILDING CLASS CATEGORY         83783 non-null  object
#  3   TAX CLASS AT PRESENT            83783 non-null  category
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
#  12  TOTAL UNITS                     83783 non-null  int64
#  13  LAND SQUARE FEET                57729 non-null  float64
#  14  GROSS SQUARE FEET               56398 non-null  float64
#  15  YEAR BUILT                      83783 non-null  int64
#  16  TAX CLASS AT TIME OF SALE       83783 non-null  category
#  17  BUILDING CLASS AT TIME OF SALE  83783 non-null  object
#  18  SALE PRICE                      69607 non-null  float64
#  19  SALE DATE                       83783 non-null  datetime64[ns]
# dtypes: category(2), datetime64[ns](1), float64(3), int64(7), object(7)
# memory usage: 12.3+ MB

# %% [markdown]
# Let's show this visually. It's easier that way to see where the NULL values are and how many there are.

# %%
# Capture the necessary data
variables = data.columns

count = []

for variable in variables:
    length = data[variable].count()
    count.append(length)
    
count_pct = np.round(100 * pd.Series(count) / len(data), 2)

# %%
#Plot number of available data per variable
plt.figure(figsize=(10,6))
plt.barh(variables, count_pct)
plt.title('Count of available data in percent', fontsize=15)
plt.show()

# %% [markdown]
# That's a shame. 20% of all Sale Prices are NULL, which is what I wanted to predict. I could still predict a price for those cases but there is no way of verifying the accuracy of the predictions. Those observations will have to be deleted.
#
# There are also around a third of all observations with missing Square Feet data. There is potential to impute those values but we will have to see how well that will work.

# %%
# Remove observations with missing SALE PRICE
data = data[data['SALE PRICE'].notnull()]
len(data)
# Out:
# 69607

# %% [markdown]
# After removing the missing SALE PRICES we are left with 70k observations, down from 85k at the very start.
#
# Now, let's get an overview of some descriptive stats of the numerical variables in the data set.

# %%
data.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  \
# count  69607.000000  69607.000000  69607.000000       69607.000000
# mean    4199.890140    374.580473  10741.159323           1.875070
# std     3431.897518    656.232024   1264.804508          14.291398
# min        1.000000      1.000000      0.000000           0.000000
# 25%     1350.000000     22.000000  10306.000000           0.000000
# 50%     3378.000000     50.000000  11209.000000           1.000000
# 75%     6192.000000    820.000000  11249.000000           2.000000
# max    16319.000000   9106.000000  11694.000000        1844.000000
#
#        COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# count      69607.000000  69607.000000      4.844900e+04       4.790000e+04
# mean           0.164121      2.059319      3.544802e+03       3.528707e+03
# std            8.997236     16.992716      3.973875e+04       2.920564e+04
# min            0.000000      0.000000      0.000000e+00       0.000000e+00
# 25%            0.000000      0.000000      1.425000e+03       8.160000e+02
# 50%            0.000000      1.000000      2.150000e+03       1.620000e+03
# 75%            0.000000      2.000000      3.100000e+03       2.508000e+03
# max         2261.000000   2261.000000      4.252327e+06       3.750565e+06
#
#          YEAR BUILT    SALE PRICE
# count  69607.000000  6.960700e+04
# mean    1799.852184  1.280703e+06
# std      520.099311  1.143036e+07
# min        0.000000  0.000000e+00
# 25%     1920.000000  2.300000e+05
# 50%     1938.000000  5.330000e+05
# 75%     1965.000000  9.500000e+05
# max     2017.000000  2.210000e+09

# %% [markdown]
# Some interesting observations to note:
#
# 1) There are **ZIP CODES** with a value of 0, which is probably wrong.
#
# 2) 75% of properties have no **COMMERCIAL UNITS**
#
# 3) At least 50% of all properties have only 1 **TOTAL UNIT**. I am not quite sure what to make of that yet.
#
# 4) There are properties have 0 **SQUARE FEET**, which shouldn't be possible unless they don't exist yet or the data is wrong.
#
# 5) Some buildings were built in the **YEAR** 0, which again is wrong.
#
# 6) Some properties have a **SALE PRICE** of 0, which is also wrong or a transfer but not actually a sale.

# %% [markdown]
# ### 2.4 data exploration (target var)

# %% [markdown]
# Again, I have already done some data inspection and I will not show those variables that aren't useful for the model. I will first look at the dependent variable **SALE PRICE**, which is the one I want to predict. After that I will look at the independent variables, which are the ones I use to predict the price.

# %% [markdown]
# **SALE PRICE**

# %% [markdown]
# Let's start with the dependent variable as this is the one I want to predict. First, some plots.

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

# Plot the data and configure the settings
sns.boxplot(x='SALE PRICE', data=data)
plt.ticklabel_format(style='plain', axis='x')
plt.title('Boxplot of SALE PRICE in USD')
plt.show()

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

# Plot the data and configure the settings
sns.distplot(data['SALE PRICE'])
plt.title('Histogram of SALE PRICE in USD')
plt.ylabel('Normed Frequency')
plt.show()

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

#Get the data and format it
x = data[['SALE PRICE']].sort_values(by='SALE PRICE').reset_index()
x['PROPERTY PROPORTION'] = 1
x['PROPERTY PROPORTION'] = x['PROPERTY PROPORTION'].cumsum()
x['PROPERTY PROPORTION'] = 100* x['PROPERTY PROPORTION'] / len(x['PROPERTY PROPORTION'])

# Plot the data and configure the settings
plt.plot(x['PROPERTY PROPORTION'],x['SALE PRICE'], linestyle='None', marker='o')
plt.title('Cumulative Distribution of Properties according to Price')
plt.xlabel('Percentage of Properties in ascending order of Price')
plt.ylabel('Sale Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# What we see from the two graphs above is that there are a lot of outliers. Maybe this isn't all that surprising given that Manhattan is home to a lot of very expensive property. From the descriptive statistics we could also tell that 75% of the properties in this dataset are cheaper than 950,000 USD. There are also a fair number of properties cheaper than 100,000 USD, which seems too cheap in my opinion.
#
# I have done a few iterations of what a good cap on sales prices is and settled for
#
# 1) property needs to be more expensive than 100,000 USD
#
# 2) property needs to be cheaper than 5,000,000 USD
#
# Everything is else is a different animal and mixing all together in one model will decrease accuracy.

# %%
# Remove observations that fall outside those caps
data = data[(data['SALE PRICE'] > 100000) & (data['SALE PRICE'] < 5000000)]
len(data)
# Out:
# 54579

# %% [markdown]
# And we're down from 70k observations to 55k, which is 79% remaining. That's a fair chunk of data. I've been toying with the idea of clustering properties on their SALE PRICE classifiying them as something like 'cheap', 'normal', 'expensive', and 'luxury' in order to avoid this issue. I will work on this in a future iteration.
#
# Anyways, let's check out the same graphs again.

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

# Plot the data and configure the settings
sns.boxplot(x='SALE PRICE', data=data)
plt.ticklabel_format(style='plain', axis='x')
plt.title('Boxplot of SALE PRICE in USD')
plt.show()

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

# Plot the data and configure the settings
sns.distplot(data['SALE PRICE'])
plt.title('Histogram of SALE PRICE in USD')
plt.ylabel('Normed Frequency')
plt.show()

# %%
#Set the size of the plot
plt.figure(figsize=(15,6))

#Get the data and format it
x = data[['SALE PRICE']].sort_values(by='SALE PRICE').reset_index()
x['PROPERTY PROPORTION'] = 1
x['PROPERTY PROPORTION'] = x['PROPERTY PROPORTION'].cumsum()
x['PROPERTY PROPORTION'] = 100* x['PROPERTY PROPORTION'] / len(x['PROPERTY PROPORTION'])

# Plot the data and configure the settings
plt.plot(x['PROPERTY PROPORTION'],x['SALE PRICE'], linestyle='None', marker='o')
plt.title('Cumulative Distribution of Properties according to Price')
plt.xlabel('Percentage of Properties in ascending order of Price')
plt.ylabel('Sale Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# **Recap and Revisit of Entire Data Set**

# %% [markdown]
# After I've removed some observations due to their prices, which I have treated as outliers, how many NULL **SQUARE FEET** observations remain?
#
# Unfortunately, there are still a third of observations remaining that contain no **SQAURE FEET** data. It turns out - **SPOILER ALERT!** that this is the best predictor of **SALE PRICE** in this dataset, which means I want to keep as much data as possible instead of just throwing them away. I'll show the importance of **SQAURE FEET** in the result section at the end of the workbook.

# %%
# Capture the necessary data
variables = data.columns

count = []

for variable in variables:
    length = data[variable].count()
    count.append(length)
    
count_pct = np.round(100 * pd.Series(count) / len(data), 2)

# %%
#Plot number of available data per variable
plt.figure(figsize=(10,6))
plt.barh(variables, count_pct)
plt.title('Count of available data in percent', fontsize=15)
plt.show()

# %% [markdown]
# ### 2.5 data exploration (features)

# %% [markdown]
# I have already looked at each variable in more detail and only show the ones I am going to keep for the model. Currently I have removed all the NULL and outlier data of **SQUARE FEET** and **TOTAL UNITS** but in a future iteration I will try to impute some data points to keep as much as data as possible.

# %% [markdown]
# **SQUARE FEET**

# %% [markdown]
# I need to get rid of the NULL values and a few outliers.

# %%
# Removes all NULL values
data = data[data['LAND SQUARE FEET'].notnull()] 
data = data[data['GROSS SQUARE FEET'].notnull()]

# %%
# Keeps properties with fewer than 20,000 Square Feet, which is about 2,000 Square Metres
data = data[data['GROSS SQUARE FEET'] < 20000]
data = data[data['LAND SQUARE FEET'] < 20000]

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='GROSS SQUARE FEET', y='SALE PRICE', data=data, fit_reg=False, scatter_kws={'alpha':0.3})
plt.title('Gross Square Feet vs Sale Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='LAND SQUARE FEET', y='SALE PRICE', data=data, fit_reg=False, scatter_kws={'alpha':0.3})
plt.title('Land Square Feet vs Sale Price')
plt.show()

# %% [markdown]
# **Total Units**

# %% [markdown]
# I am deleting the outliers with very large numbers of **TOTAL UNITS** and those with 0 units. Those are only a handful of observations though. In addition, I get rid of the observations the sum of **COMMERCIAL UNITS** and **RESIDENTIAL UNITS** doesn't match **TOTAL UNITS**.

# %%
# Only a handful of properties with 0 total units are remaining and they will now be deleted
data = data[(data['TOTAL UNITS'] > 0) & (data['TOTAL UNITS'] < 50)]

# %%
#Remove data where commercial + residential doesn't equal total units
data = data[data['TOTAL UNITS'] == data['COMMERCIAL UNITS'] + data['RESIDENTIAL UNITS']]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='COMMERCIAL UNITS', y='SALE PRICE', data=data)
plt.title('Commercial Units vs Sale Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='RESIDENTIAL UNITS', y='SALE PRICE', data=data)
plt.title('Residential Units vs Sale Price')
plt.show()

# %% [markdown]
# **YEAR BUILT**

# %% [markdown]
# Next one up is YEAR BUILT. There seem to be some buildings that were built in the year 0, which can't be correct. Let's remove those.

# %%
data = data[data['YEAR BUILT'] > 0]

# %% [markdown]
# What does the plot look like now? OK, that's a lot more realistic.

# %% [markdown]
# However, **YEAR BUILT** isn't quite the variable we are looking for. What is more interesting is the **BUILDING AGE**. Both contain similar information, the second is however a bit more practical. So, let's create it.

# %%
data['BUILDING AGE'] = 2017 - data['YEAR BUILT']

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='BUILDING AGE', y='SALE PRICE', data=data, fit_reg=False, scatter_kws={'alpha':0.1})
plt.title('Sale Price Distribution by Building Age')
plt.show()

# %% [markdown]
# **BOROUGH**

# %% [markdown]
# This is all in good shape and no surpises here.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='BOROUGH', y='SALE PRICE', data=data)
plt.title('Sale Price Distribution by Borough')
plt.show()

# %% [markdown]
# **Building Class Category**

# %% [markdown]
# Some of the categories could potentially be merged in a future iteration.

# %%
plt.figure(figsize=(10,6))
order = sorted(data['BUILDING CLASS CATEGORY'].unique())
sns.boxplot(x='BUILDING CLASS CATEGORY', y='SALE PRICE', data=data, order=order)
plt.xticks(rotation=90)
plt.title('Sale Price Distribution by Bulding Class Category')
plt.show()

# %% [markdown]
# **More Data Visualisations**

# %%
# Correlation Matrix

# Compute the correlation matrix
d= data[['TOTAL UNITS','GROSS SQUARE FEET','SALE PRICE', 'BUILDING AGE', 'LAND SQUARE FEET', 'RESIDENTIAL UNITS', 
         'COMMERCIAL UNITS']]
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, 
            square=True, linewidths=.5, annot=True, cmap=cmap)
plt.yticks(rotation=0)
plt.title('Correlation Matrix of all Numerical Variables')
plt.show()

# %% [markdown]
# # -3- modeling
# * data preparation
# * splitting into train/test
# * fit a linear regressor, evaluate predictions
# * fit a random forest regressor, evaluate predictions

# %% [markdown]
# #### 3.1 data preparation

# %% [markdown]
# scikit works best with normalized data, i.e. data that has a mean around 0 and a distribution around that. In the next section I will normalise/standardise the data and also take the log in order to get rid of the skewness and to allow for a more normal distribution.
#
# But first I get all the relevant variables and one-hot encode the categrical variables, which is necessary for scikit to work. The numerical variables don't need one-hot encoding but will have to be normalised.

# %%
#Choose only the variables I want to use in the model
columns = ['BOROUGH', 'BUILDING CLASS CATEGORY', 'COMMERCIAL UNITS','GROSS SQUARE FEET',
       'SALE PRICE', 'BUILDING AGE', 'LAND SQUARE FEET', 'RESIDENTIAL UNITS']
data_model = data.loc[:,columns]

# %%
#Select the variables to be one-hot encoded
one_hot_features = ['BOROUGH', 'BUILDING CLASS CATEGORY']

# For each categorical column, find the unique number of categories. This tells us how many columns we are adding to the dataset.
longest_str = max(one_hot_features, key=len)
total_num_unique_categorical = 0
for feature in one_hot_features:
    num_unique = len(data[feature].unique())
    print('{col:<{fill_col}} : {num:d} unique categorical values.'.format(col=feature, 
                                                                          fill_col=len(longest_str),
                                                                          num=num_unique))
    total_num_unique_categorical += num_unique
print('{total:d} columns will be added during one-hot encoding.'.format(total=total_num_unique_categorical))
# Out:
# BOROUGH                 : 5 unique categorical values.
# BUILDING CLASS CATEGORY : 31 unique categorical values.
# 36 columns will be added during one-hot encoding.

# %%
# Convert categorical variables into dummy/indicator variables (i.e. one-hot encoding).
one_hot_encoded = pd.get_dummies(data_model[one_hot_features])
one_hot_encoded.info(verbose=True, memory_usage=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29638 entries, 3 to 84545
# Data columns (total 36 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   BOROUGH_Bronx                                                         29638 non-null  uint8
#  1   BOROUGH_Brooklyn                                                      29638 non-null  uint8
#  2   BOROUGH_Manhattan                                                     29638 non-null  uint8
#  3   BOROUGH_Queens                                                        29638 non-null  uint8
#  4   BOROUGH_Staten Island                                                 29638 non-null  uint8
#  5   BUILDING CLASS CATEGORY_01 ONE FAMILY DWELLINGS                       29638 non-null  uint8
#  6   BUILDING CLASS CATEGORY_02 TWO FAMILY DWELLINGS                       29638 non-null  uint8
#  7   BUILDING CLASS CATEGORY_03 THREE FAMILY DWELLINGS                     29638 non-null  uint8
#  8   BUILDING CLASS CATEGORY_04 TAX CLASS 1 CONDOS                         29638 non-null  uint8
#  9   BUILDING CLASS CATEGORY_05 TAX CLASS 1 VACANT LAND                    29638 non-null  uint8
#  10  BUILDING CLASS CATEGORY_06 TAX CLASS 1 - OTHER                        29638 non-null  uint8
#  11  BUILDING CLASS CATEGORY_07 RENTALS - WALKUP APARTMENTS                29638 non-null  uint8
#  12  BUILDING CLASS CATEGORY_08 RENTALS - ELEVATOR APARTMENTS              29638 non-null  uint8
#  13  BUILDING CLASS CATEGORY_09 COOPS - WALKUP APARTMENTS                  29638 non-null  uint8
#  14  BUILDING CLASS CATEGORY_10 COOPS - ELEVATOR APARTMENTS                29638 non-null  uint8
#  15  BUILDING CLASS CATEGORY_11A CONDO-RENTALS                             29638 non-null  uint8
#  16  BUILDING CLASS CATEGORY_12 CONDOS - WALKUP APARTMENTS                 29638 non-null  uint8
#  17  BUILDING CLASS CATEGORY_13 CONDOS - ELEVATOR APARTMENTS               29638 non-null  uint8
#  18  BUILDING CLASS CATEGORY_14 RENTALS - 4-10 UNIT                        29638 non-null  uint8
#  19  BUILDING CLASS CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL             29638 non-null  uint8
#  20  BUILDING CLASS CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT    29638 non-null  uint8
#  21  BUILDING CLASS CATEGORY_21 OFFICE BUILDINGS                           29638 non-null  uint8
#  22  BUILDING CLASS CATEGORY_22 STORE BUILDINGS                            29638 non-null  uint8
#  23  BUILDING CLASS CATEGORY_23 LOFT BUILDINGS                             29638 non-null  uint8
#  24  BUILDING CLASS CATEGORY_26 OTHER HOTELS                               29638 non-null  uint8
#  25  BUILDING CLASS CATEGORY_27 FACTORIES                                  29638 non-null  uint8
#  26  BUILDING CLASS CATEGORY_28 COMMERCIAL CONDOS                          29638 non-null  uint8
#  27  BUILDING CLASS CATEGORY_29 COMMERCIAL GARAGES                         29638 non-null  uint8
#  28  BUILDING CLASS CATEGORY_30 WAREHOUSES                                 29638 non-null  uint8
#  29  BUILDING CLASS CATEGORY_31 COMMERCIAL VACANT LAND                     29638 non-null  uint8
#  30  BUILDING CLASS CATEGORY_32 HOSPITAL AND HEALTH FACILITIES             29638 non-null  uint8
#  31  BUILDING CLASS CATEGORY_33 EDUCATIONAL FACILITIES                     29638 non-null  uint8
#  32  BUILDING CLASS CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES      29638 non-null  uint8
#  33  BUILDING CLASS CATEGORY_37 RELIGIOUS FACILITIES                       29638 non-null  uint8
#  34  BUILDING CLASS CATEGORY_38 ASYLUMS AND HOMES                          29638 non-null  uint8
#  35  BUILDING CLASS CATEGORY_41 TAX CLASS 4 - OTHER                        29638 non-null  uint8
# dtypes: uint8(36)
# memory usage: 2.3 MB

# %%
#Delete the old columns...
data_model = data_model.drop(one_hot_features, axis=1)

#...and add the new one-hot encoded variables
data_model = pd.concat([data_model, one_hot_encoded], axis=1)
data_model.head()
# Out:
#      COMMERCIAL UNITS  GROSS SQUARE FEET  SALE PRICE  BUILDING AGE  \
# 3                   0             6794.0   3936272.0           104
# 6                   0             4226.0   3192840.0            97
# 172                 1             3360.0   3300000.0           107
# 174                 1             3713.0   4750000.0           107
# 195                 1             3586.0   3700000.0           118
#
#      LAND SQUARE FEET  RESIDENTIAL UNITS  BOROUGH_Bronx  BOROUGH_Brooklyn  \
# 3              2272.0                 10              0                 0
# 6              1750.0                  8              0                 0
# 172            1520.0                  3              0                 0
# 174            1779.0                  5              0                 0
# 195            1218.0                  0              0                 0
#
#      BOROUGH_Manhattan  BOROUGH_Queens  BOROUGH_Staten Island  \
# 3                    1               0                      0
# 6                    1               0                      0
# 172                  1               0                      0
# 174                  1               0                      0
# 195                  1               0                      0
#
#      BUILDING CLASS CATEGORY_01 ONE FAMILY DWELLINGS                      \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_02 TWO FAMILY DWELLINGS                      \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_03 THREE FAMILY DWELLINGS                    \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_04 TAX CLASS 1 CONDOS                        \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_05 TAX CLASS 1 VACANT LAND                   \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_06 TAX CLASS 1 - OTHER                       \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_07 RENTALS - WALKUP APARTMENTS               \
# 3                                                    1
# 6                                                    1
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_08 RENTALS - ELEVATOR APARTMENTS             \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_09 COOPS - WALKUP APARTMENTS                 \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_10 COOPS - ELEVATOR APARTMENTS               \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_11A CONDO-RENTALS                             \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_12 CONDOS - WALKUP APARTMENTS                \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_13 CONDOS - ELEVATOR APARTMENTS              \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_14 RENTALS - 4-10 UNIT                       \
# 3                                                    0
# 6                                                    0
# 172                                                  1
# 174                                                  1
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL            \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT   \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_21 OFFICE BUILDINGS                          \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_22 STORE BUILDINGS                           \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  1
#
#      BUILDING CLASS CATEGORY_23 LOFT BUILDINGS                            \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_26 OTHER HOTELS                              \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_27 FACTORIES                                 \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_28 COMMERCIAL CONDOS                         \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_29 COMMERCIAL GARAGES                        \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_30 WAREHOUSES                                \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_31 COMMERCIAL VACANT LAND                    \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_32 HOSPITAL AND HEALTH FACILITIES            \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_33 EDUCATIONAL FACILITIES                    \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES     \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_37 RELIGIOUS FACILITIES                      \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_38 ASYLUMS AND HOMES                         \
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0
#
#      BUILDING CLASS CATEGORY_41 TAX CLASS 4 - OTHER
# 3                                                    0
# 6                                                    0
# 172                                                  0
# 174                                                  0
# 195                                                  0

# %% [markdown]
# **Transforming the dependent variable SALE PRICE**

# %% [markdown]
# This is what SALE PRICE looks before the transformation...

# %%
plt.figure(figsize=(10,6))
sns.distplot(data_model['SALE PRICE'])
plt.title('Histogram of SALE PRICE')
plt.show()

# %%
# Take the log and normalise
data_model['SALE PRICE'] = StandardScaler().fit_transform(np.log(data_model['SALE PRICE']).values.reshape(-1,1))

# %% [markdown]
# ...and  this what it looks after

# %%
plt.figure(figsize=(10,6))
sns.distplot(data_model['SALE PRICE'])
plt.title('Histogram of Normalised SALE PRICE')
plt.show()

# %% [markdown]
# **Transforming the independent variables**

# %% [markdown]
# Some of the variables contain zeroes, which is why I need to add 1 so that I can take the log before normalising it - you can see that in the table below. Using the log allows me to get rid of the skew in the data and have a more normal distribution. The reason why I need to add 1 is because I can't take the log of 0 - it is not defined. The log of 1 however is.

# %%
data_model.describe()
# Out:
#        COMMERCIAL UNITS  GROSS SQUARE FEET    SALE PRICE  BUILDING AGE  \
# count      29638.000000       29638.000000  2.963800e+04  29638.000000
# mean           0.086949        1930.882347 -9.206033e-17     70.616135
# std            0.455198        1524.886820  1.000017e+00     34.974586
# min            0.000000           0.000000 -3.013746e+00      0.000000
# 25%            0.000000        1216.000000 -6.303558e-01     52.000000
# 50%            0.000000        1680.000000 -5.826635e-02     82.000000
# 75%            0.000000        2392.000000  5.592114e-01     97.000000
# max           25.000000       19892.000000  3.195120e+00    217.000000
#
#        LAND SQUARE FEET  RESIDENTIAL UNITS  BOROUGH_Bronx  BOROUGH_Brooklyn  \
# count      29638.000000       29638.000000   29638.000000      29638.000000
# mean        2723.698326           1.727175       0.113031          0.364498
# std         1926.963113           1.518719       0.316636          0.481297
# min            0.000000           0.000000       0.000000          0.000000
# 25%         1832.000000           1.000000       0.000000          0.000000
# 50%         2417.500000           1.000000       0.000000          0.000000
# 75%         3495.750000           2.000000       0.000000          1.000000
# max        19500.000000          48.000000       1.000000          1.000000
#
#        BOROUGH_Manhattan  BOROUGH_Queens  BOROUGH_Staten Island  \
# count       29638.000000    29638.000000           29638.000000
# mean            0.009414        0.351542               0.161516
# std             0.096568        0.477460               0.368012
# min             0.000000        0.000000               0.000000
# 25%             0.000000        0.000000               0.000000
# 50%             0.000000        0.000000               0.000000
# 75%             0.000000        1.000000               0.000000
# max             1.000000        1.000000               1.000000
#
#        BUILDING CLASS CATEGORY_01 ONE FAMILY DWELLINGS                      \
# count                                       29638.000000
# mean                                            0.415919
# std                                             0.492888
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_02 TWO FAMILY DWELLINGS                      \
# count                                       29638.000000
# mean                                            0.321074
# std                                             0.466897
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_03 THREE FAMILY DWELLINGS                    \
# count                                       29638.000000
# mean                                            0.075477
# std                                             0.264165
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_04 TAX CLASS 1 CONDOS                        \
# count                                       29638.000000
# mean                                            0.012416
# std                                             0.110737
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_05 TAX CLASS 1 VACANT LAND                   \
# count                                       29638.000000
# mean                                            0.000810
# std                                             0.028445
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_06 TAX CLASS 1 - OTHER                       \
# count                                       29638.000000
# mean                                            0.000236
# std                                             0.015367
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_07 RENTALS - WALKUP APARTMENTS               \
# count                                       29638.000000
# mean                                            0.044369
# std                                             0.205916
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_08 RENTALS - ELEVATOR APARTMENTS             \
# count                                       29638.000000
# mean                                            0.000236
# std                                             0.015367
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_09 COOPS - WALKUP APARTMENTS                 \
# count                                       29638.000000
# mean                                            0.000034
# std                                             0.005809
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_10 COOPS - ELEVATOR APARTMENTS               \
# count                                       29638.000000
# mean                                            0.000034
# std                                             0.005809
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_11A CONDO-RENTALS                             \
# count                                       29638.000000
# mean                                            0.000270
# std                                             0.016427
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_12 CONDOS - WALKUP APARTMENTS                \
# count                                       29638.000000
# mean                                            0.007996
# std                                             0.089066
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_13 CONDOS - ELEVATOR APARTMENTS              \
# count                                       29638.000000
# mean                                            0.060632
# std                                             0.238657
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_14 RENTALS - 4-10 UNIT                       \
# count                                       29638.000000
# mean                                            0.009582
# std                                             0.097421
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL            \
# count                                       29638.000000
# mean                                            0.022167
# std                                             0.147231
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT   \
# count                                       29638.000000
# mean                                            0.000405
# std                                             0.020118
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_21 OFFICE BUILDINGS                          \
# count                                       29638.000000
# mean                                            0.003846
# std                                             0.061901
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_22 STORE BUILDINGS                           \
# count                                       29638.000000
# mean                                            0.011472
# std                                             0.106492
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_23 LOFT BUILDINGS                            \
# count                                       29638.000000
# mean                                            0.000135
# std                                             0.011617
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_26 OTHER HOTELS                              \
# count                                       29638.000000
# mean                                            0.000135
# std                                             0.011617
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_27 FACTORIES                                 \
# count                                       29638.000000
# mean                                            0.002092
# std                                             0.045690
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_28 COMMERCIAL CONDOS                         \
# count                                       29638.000000
# mean                                            0.000034
# std                                             0.005809
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_29 COMMERCIAL GARAGES                        \
# count                                       29638.000000
# mean                                            0.004251
# std                                             0.065064
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_30 WAREHOUSES                                \
# count                                       29638.000000
# mean                                            0.003610
# std                                             0.059978
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_31 COMMERCIAL VACANT LAND                    \
# count                                       29638.000000
# mean                                            0.000169
# std                                             0.012988
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_32 HOSPITAL AND HEALTH FACILITIES            \
# count                                       29638.000000
# mean                                            0.000304
# std                                             0.017424
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_33 EDUCATIONAL FACILITIES                    \
# count                                       29638.000000
# mean                                            0.000405
# std                                             0.020118
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES     \
# count                                       29638.000000
# mean                                            0.000270
# std                                             0.016427
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_37 RELIGIOUS FACILITIES                      \
# count                                       29638.000000
# mean                                            0.001215
# std                                             0.034831
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_38 ASYLUMS AND HOMES                         \
# count                                       29638.000000
# mean                                            0.000135
# std                                             0.011617
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        BUILDING CLASS CATEGORY_41 TAX CLASS 4 - OTHER
# count                                       29638.000000
# mean                                            0.000270
# std                                             0.016427
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000

# %% [markdown]
# **UNITS**

# %%
# Add 1 to Units
data_model['COMMERCIAL UNITS'] = data_model['COMMERCIAL UNITS'] + 1
data_model['RESIDENTIAL UNITS'] = data_model['RESIDENTIAL UNITS'] + 1

# Take the log and standardise
data_model['COMMERCIAL UNITS'] = StandardScaler().fit_transform(np.log(data_model['COMMERCIAL UNITS']).values.reshape(-1,1))
data_model['RESIDENTIAL UNITS'] = StandardScaler().fit_transform(np.log(data_model['RESIDENTIAL UNITS']).values.reshape(-1,1))

# %% [markdown]
# **SQUARE FEET**

# %%
# Add 1 to Units
data_model['GROSS SQUARE FEET'] = data_model['GROSS SQUARE FEET'] + 1
data_model['LAND SQUARE FEET'] = data_model['LAND SQUARE FEET'] + 1

# Take the log and standardise
data_model['GROSS SQUARE FEET'] = StandardScaler().fit_transform(np.log(data_model['GROSS SQUARE FEET']).values.reshape(-1,1))
data_model['LAND SQUARE FEET'] = StandardScaler().fit_transform(np.log(data_model['LAND SQUARE FEET']).values.reshape(-1,1))

# %% [markdown]
# **BUILDING AGE**

# %%
# Add 1 to BUILDING AGE
data_model['BUILDING AGE'] = data_model['BUILDING AGE'] + 1

# Take the log and standardise
data_model['BUILDING AGE'] = StandardScaler().fit_transform(np.log(data_model['BUILDING AGE']).values.reshape(-1,1))

# %% [markdown]
# ### 3.2 splitting the data (train/test)

# %% [markdown]
# The step is necessary to ensure that the model is flexible and general enough so that can predict accurately unseen or new data. I train the model with the training data and then check how good it performs on the unseen testing data.

# %%
#Split data into training and testing set with 80% of the data going into training
training, testing = train_test_split(data_model, test_size=0.2, random_state=0)
print("Total sample size = %i; training sample size = %i, testing sample size = %i"\
     %(data_model.shape[0],training.shape[0],testing.shape[0]))
# Out:
# Total sample size = 29638; training sample size = 23710, testing sample size = 5928

# %%
#X are the variables/features that help predict y, which tells us whether an employee left or stayed. This is done for both 
#training and testing
df_train_s = training.loc[:,data_model.columns]
X_train_s = df_train_s.drop(['SALE PRICE'], axis=1)
y_train_s = df_train_s.loc[:, ['SALE PRICE']]

df_test_s = testing.loc[:,data_model.columns]
X_test_s = df_test_s.drop(['SALE PRICE'], axis=1)
y_test_s = df_test_s.loc[:, ['SALE PRICE']]

# %% [markdown]
# Finally, the moment we have all been waiting for. I will now test a couple of different models to see which one performs best... note, does not include any parameter tuning.
#
# I will use
#
# 1) **Linear Regression**
#
# 2) **Random Forest Regression**

# %% [markdown]
# ### 3.3 linear regression model

# %% [markdown]
# fit the model

# %%
# Create the regressor: linreg
linreg = LinearRegression()

# Fit the regressor to the training data
linreg.fit(X_train_s, y_train_s)

# Predict the labels of the test set: y_pred
y_pred_s = linreg.predict(X_test_s)

# Compute 5-fold cross-validation scores: cv_scores
cv_scores_linreg = cross_val_score(linreg, X_train_s, y_train_s, cv=5)

# %% [markdown]
# evaluate the model

# %%
print("R^2: {}".format(linreg.score(X_test_s, y_test_s)))
rmse = np.sqrt(mean_squared_error(y_test_s, y_pred_s))
print("Root Mean Squared Error: {}".format(rmse))

print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores_linreg)))
# Print the 5-fold cross-validation scores
print(cv_scores_linreg)
# Out:
# R^2: 0.363235389600268
# Root Mean Squared Error: 0.8088975943993005
# Average 5-Fold CV Score: -9.629571584296036e+17
# [ 3.54379257e-01 -4.69178411e+18  3.46260912e-01  3.51796262e-01
#  -1.23001677e+17]

# %% [markdown]
# ### 3.4 random forest regressor

# %% [markdown]
# fit the model

# %%
rf_reg = RandomForestRegressor()

rf_reg.fit(X_train_s, y_train_s)

y_pred_s_rf = rf_reg.predict(X_test_s)

# Compute 5-fold cross-validation scores: cv_scores
cv_scores_rf = cross_val_score(rf_reg, X_train_s, y_train_s, cv=5)

# %% [markdown]
# evaluate the model

# %%
print("R^2: {}".format(rf_reg.score(X_test_s, y_test_s)))
rmse = np.sqrt(mean_squared_error(y_test_s, y_pred_s_rf))
print("Root Mean Squared Error: {}".format(rmse))

print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores_rf)))
# Print the 5-fold cross-validation scores
print(cv_scores_rf)
# Out:
# R^2: 0.4301803498448885
# Root Mean Squared Error: 0.7651961838559912
# Average 5-Fold CV Score: 0.41793472998339637
# [0.42233411 0.45860989 0.39195547 0.41683755 0.39993663]

# %% [markdown]
# interpret the model

# %%
importance = pd.DataFrame(list(zip(X_train_s.columns, np.transpose(rf_reg.feature_importances_))) \
            ).sort_values(1, ascending=False)
importance
# Out:
#                                                     0         1
# 1                                   GROSS SQUARE FEET  0.408426
# 3                                    LAND SQUARE FEET  0.189618
# 2                                        BUILDING AGE  0.144463
# 6                                    BOROUGH_Brooklyn  0.085336
# 5                                       BOROUGH_Bronx  0.034897
# 8                                      BOROUGH_Queens  0.025747
# 4                                   RESIDENTIAL UNITS  0.024755
# 22  BUILDING CLASS CATEGORY_13 CONDOS - ELEVATOR A...  0.017219
# 7                                   BOROUGH_Manhattan  0.011431
# 9                               BOROUGH_Staten Island  0.009549
# 0                                    COMMERCIAL UNITS  0.008840
# 10  BUILDING CLASS CATEGORY_01 ONE FAMILY DWELLING...  0.008185
# 11  BUILDING CLASS CATEGORY_02 TWO FAMILY DWELLING...  0.007816
# 12  BUILDING CLASS CATEGORY_03 THREE FAMILY DWELLI...  0.004720
# 27  BUILDING CLASS CATEGORY_22 STORE BUILDINGS    ...  0.002431
# 16  BUILDING CLASS CATEGORY_07 RENTALS - WALKUP AP...  0.002304
# 21  BUILDING CLASS CATEGORY_12 CONDOS - WALKUP APA...  0.002058
# 23  BUILDING CLASS CATEGORY_14 RENTALS - 4-10 UNIT...  0.001822
# 32  BUILDING CLASS CATEGORY_29 COMMERCIAL GARAGES ...  0.001699
# 13  BUILDING CLASS CATEGORY_04 TAX CLASS 1 CONDOS ...  0.001396
# 26  BUILDING CLASS CATEGORY_21 OFFICE BUILDINGS   ...  0.001137
# 33  BUILDING CLASS CATEGORY_30 WAREHOUSES         ...  0.001131
# 24  BUILDING CLASS CATEGORY_15 CONDOS - 2-10 UNIT ...  0.001047
# 14  BUILDING CLASS CATEGORY_05 TAX CLASS 1 VACANT ...  0.000962
# 30  BUILDING CLASS CATEGORY_27 FACTORIES          ...  0.000734
# 38  BUILDING CLASS CATEGORY_37 RELIGIOUS FACILITIE...  0.000502
# 37  BUILDING CLASS CATEGORY_35 INDOOR PUBLIC AND C...  0.000309
# 34  BUILDING CLASS CATEGORY_31 COMMERCIAL VACANT L...  0.000241
# 18  BUILDING CLASS CATEGORY_09 COOPS - WALKUP APAR...  0.000225
# 19  BUILDING CLASS CATEGORY_10 COOPS - ELEVATOR AP...  0.000180
# 15  BUILDING CLASS CATEGORY_06 TAX CLASS 1 - OTHER...  0.000153
# 36  BUILDING CLASS CATEGORY_33 EDUCATIONAL FACILIT...  0.000134
# 39  BUILDING CLASS CATEGORY_38 ASYLUMS AND HOMES  ...  0.000104
# 20  BUILDING CLASS CATEGORY_11A CONDO-RENTALS     ...  0.000096
# 35  BUILDING CLASS CATEGORY_32 HOSPITAL AND HEALTH...  0.000086
# 25  BUILDING CLASS CATEGORY_16 CONDOS - 2-10 UNIT ...  0.000084
# 40  BUILDING CLASS CATEGORY_41 TAX CLASS 4 - OTHER...  0.000083
# 17  BUILDING CLASS CATEGORY_08 RENTALS - ELEVATOR ...  0.000047
# 28  BUILDING CLASS CATEGORY_23 LOFT BUILDINGS     ...  0.000019
# 29  BUILDING CLASS CATEGORY_26 OTHER HOTELS       ...  0.000015
# 31  BUILDING CLASS CATEGORY_28 COMMERCIAL CONDOS  ...  0.000000

# %%
importances = rf_reg.feature_importances_

std = np.std([tree.feature_importances_ for tree in rf_reg.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_train_s.shape[1]), importances[indices],  
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X_train_s.shape[1]),X_train_s.columns[indices], rotation=90)
#plt.xlim([-1, X_train_s.shape[1]])
plt.xlim([-1, 10])
plt.show()

# %% [markdown]
# # -4- conclusion & next steps

# %% [markdown]
# 1) An untuned Random Forest Regression managed to get a R2 of > 0.40, which is certainly not great but maybe not bad given the limited amount of data available. **SQUARE FEET**, **BUILDING AGE**, and **BOROUGH** were the most important features determining the **SALE PRICE**.
#
# 2) We only used 30k observations out of a potential of 70k. Remember that there were a fair amount of NULL **SALE PRICE** observations and duplicates etc. So the original 85k don't count. In a next iteration I will therefore explore the possibilities to impute the **SQUARE FEET** data because I deleted a lot here. The same is true for **UNITS** data.
#
# 3) Instead of throwing outlier **SALE PRICE** data I will try to use clustering to classify properties,w hich would allow me to keep the outlier data - maybe.
